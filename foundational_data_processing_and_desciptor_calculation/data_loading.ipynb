# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import PandasTools

# Load the CSV file into a Pandas DataFrame

refcode_csv = pd.read_csv('sohncke_vs_rac_table.csv')

refcode = refcode_csv['refcode_stem']
delta_E_in_kJmol = refcode_csv['Delta_E_in_kJ/mol']
delta_den_in_percent = refcode_csv['Delta_den_in_percent']

df = pd.DataFrame({'REFCODE': refcode, 'Change in Energy (kJ mol-1)': delta_E_in_kJmol, 'Change in Density (%)': delta_den_in_percent})

# Display the first few rows of the DataFrame

df
# Out:
#     REFCODE  Change in Energy (kJ mol-1)  Change in Density (%)
# 0    ABUDAD                       0.3826                -0.2392
# 1    AFUNEV                       0.2955                -1.9416
# 2    ANONIN                       3.8249                -0.3280
# 3    APUHOJ                      -2.3110                 0.4213
# 4    ATIBAH                       6.6306                -3.9703
# ..      ...                          ...                    ...
# 351  ZORQIG                       4.5287                -6.1786
# 352  ZOTCTD                       8.0495                -3.8482
# 353  ZTCDON                       3.8340                -0.9538
# 354  ZTNONX                       1.5668                -2.0031
# 355  ZUMKUN                       2.9396                -5.2153
#
# [356 rows x 3 columns]

# %%
print(refcode)
# Out:
# 0      ABUDAD
# 1      AFUNEV
# 2      ANONIN
# 3      APUHOJ
# 4      ATIBAH
#         ...
# 351    ZORQIG
# 352    ZOTCTD
# 353    ZTCDON
# 354    ZTNONX
# 355    ZUMKUN
# Name: refcode_stem, Length: 356, dtype: object
